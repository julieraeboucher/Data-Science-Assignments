# %%
import pandas as pd

# %%
ht = pd.read_csv("/Users/julieraeboucher/Desktop/Work/Datasets/HT_2013-2021/HT_2013-2021.csv")

# %%
ht
# Out:
#       DATA_YEAR        ORI                             PUB_AGENCY_NAME  \
# 0          2013  MO0950000          St. Louis County Police Department
# 1          2013  OH0020000                                       Allen
# 2          2013  OH0020000                                       Allen
# 3          2013  TN0320100                                  Morristown
# 4          2013  TNMPD0000                                     Memphis
# ...         ...        ...                                         ...
# 3093       2021  WY0010100                                     Laramie
# 3094       2021  WY0010100                                     Laramie
# 3095       2021  WY0050000                                    Converse
# 3096       2021  WY0080100                                  Torrington
# 3097       2021  WY0110400  Wyoming Division of Criminal Investigation
#
#      PUB_AGENCY_UNIT    AGENCY_TYPE_NAME STATE_ABBR STATE_NAME  \
# 0                NaN              County         MO   Missouri
# 1                NaN              County         OH       Ohio
# 2                NaN              County         OH       Ohio
# 3                NaN                City         TN  Tennessee
# 4                NaN                City         TN  Tennessee
# ...              ...                 ...        ...        ...
# 3093             NaN                City         WY    Wyoming
# 3094             NaN                City         WY    Wyoming
# 3095             NaN              County         WY    Wyoming
# 3096             NaN                City         WY    Wyoming
# 3097             NaN  Other State Agency         WY    Wyoming
#
#            DIVISION_NAME         COUNTY_NAME REGION_NAME  \
# 0     West North Central            ST LOUIS     Midwest
# 1     East North Central               ALLEN     Midwest
# 2     East North Central               ALLEN     Midwest
# 3     East South Central  HAMBLEN, JEFFERSON       South
# 4     East South Central              SHELBY       South
# ...                  ...                 ...         ...
# 3093            Mountain              ALBANY        West
# 3094            Mountain              ALBANY        West
# 3095            Mountain            CONVERSE        West
# 3096            Mountain              GOSHEN        West
# 3097            Mountain             LARAMIE        West
#
#      POPULATION_GROUP_CODE                 POPULATION_GROUP_DESC  \
# 0                       9A          MSA counties 100,000 or over
# 1                       9C  MSA counties from 10,000 thru 24,999
# 2                       9C  MSA counties from 10,000 thru 24,999
# 3                        4        Cities from 25,000 thru 49,999
# 4                       1B      Cities from 500,000 thru 999,999
# ...                    ...                                   ...
# 3093                     4        Cities from 25,000 thru 49,999
# 3094                     4        Cities from 25,000 thru 49,999
# 3095                    8D         Non-MSA counties under 10,000
# 3096                     6          Cities from 2,500 thru 9,999
# 3097                    9D             MSA counties under 10,000
#
#      OFFENSE_SUBCAT_ID       OFFENSE_NAME    OFFENSE_SUBCAT_NAME  \
# 0                HTCSA  Human Trafficking    Commercial Sex Acts
# 1                HTCSA  Human Trafficking    Commercial Sex Acts
# 2                 HTIS  Human Trafficking  Involuntary Servitude
# 3                HTCSA  Human Trafficking    Commercial Sex Acts
# 4                HTCSA  Human Trafficking    Commercial Sex Acts
# ...                ...                ...                    ...
# 3093             HTCSA  Human Trafficking    Commercial Sex Acts
# 3094              HTIS  Human Trafficking  Involuntary Servitude
# 3095             HTCSA  Human Trafficking    Commercial Sex Acts
# 3096              HTIS  Human Trafficking  Involuntary Servitude
# 3097              HTIS  Human Trafficking  Involuntary Servitude
#
#       ACTUAL_COUNT  UNFOUNDED_COUNT  CLEARED_COUNT  JUVENILE_CLEARED_COUNT
# 0              384              0.0            384                       0
# 1               64              0.0             64                       0
# 2               64              0.0              0                       0
# 3               64              0.0             64                       0
# 4              192              0.0            128                       0
# ...            ...              ...            ...                     ...
# 3093           128              NaN              0                       0
# 3094            64              NaN              0                       0
# 3095           128              NaN            128                       0
# 3096           128              NaN             64                       0
# 3097            20              NaN              8                       0
#
# [3098 rows x 19 columns]

# %%
ht.head()
# Out:
#    DATA_YEAR        ORI                     PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# 0       2013  MO0950000  St. Louis County Police Department             NaN
# 1       2013  OH0020000                               Allen             NaN
# 2       2013  OH0020000                               Allen             NaN
# 3       2013  TN0320100                          Morristown             NaN
# 4       2013  TNMPD0000                             Memphis             NaN
#
#   AGENCY_TYPE_NAME STATE_ABBR STATE_NAME       DIVISION_NAME  \
# 0           County         MO   Missouri  West North Central
# 1           County         OH       Ohio  East North Central
# 2           County         OH       Ohio  East North Central
# 3             City         TN  Tennessee  East South Central
# 4             City         TN  Tennessee  East South Central
#
#           COUNTY_NAME REGION_NAME POPULATION_GROUP_CODE  \
# 0            ST LOUIS     Midwest                    9A
# 1               ALLEN     Midwest                    9C
# 2               ALLEN     Midwest                    9C
# 3  HAMBLEN, JEFFERSON       South                     4
# 4              SHELBY       South                    1B
#
#                   POPULATION_GROUP_DESC OFFENSE_SUBCAT_ID       OFFENSE_NAME  \
# 0          MSA counties 100,000 or over             HTCSA  Human Trafficking
# 1  MSA counties from 10,000 thru 24,999             HTCSA  Human Trafficking
# 2  MSA counties from 10,000 thru 24,999              HTIS  Human Trafficking
# 3        Cities from 25,000 thru 49,999             HTCSA  Human Trafficking
# 4      Cities from 500,000 thru 999,999             HTCSA  Human Trafficking
#
#      OFFENSE_SUBCAT_NAME  ACTUAL_COUNT  UNFOUNDED_COUNT  CLEARED_COUNT  \
# 0    Commercial Sex Acts           384              0.0            384
# 1    Commercial Sex Acts            64              0.0             64
# 2  Involuntary Servitude            64              0.0              0
# 3    Commercial Sex Acts            64              0.0             64
# 4    Commercial Sex Acts           192              0.0            128
#
#    JUVENILE_CLEARED_COUNT
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0

# %% [markdown]
# ---

# %% [markdown]
# # Columns and Column Variables

# %%
ht.columns
# Out:
# Index(['DATA_YEAR', 'ORI', 'PUB_AGENCY_NAME', 'PUB_AGENCY_UNIT',
#        'AGENCY_TYPE_NAME', 'STATE_ABBR', 'STATE_NAME', 'DIVISION_NAME',
#        'COUNTY_NAME', 'REGION_NAME', 'POPULATION_GROUP_CODE',
#        'POPULATION_GROUP_DESC', 'OFFENSE_SUBCAT_ID', 'OFFENSE_NAME',
#        'OFFENSE_SUBCAT_NAME', 'ACTUAL_COUNT', 'UNFOUNDED_COUNT',
#        'CLEARED_COUNT', 'JUVENILE_CLEARED_COUNT'],
#       dtype='object')

# %%
ht.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3098 entries, 0 to 3097
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DATA_YEAR               3098 non-null   int64
#  1   ORI                     3098 non-null   object
#  2   PUB_AGENCY_NAME         3098 non-null   object
#  3   PUB_AGENCY_UNIT         231 non-null    object
#  4   AGENCY_TYPE_NAME        3098 non-null   object
#  5   STATE_ABBR              3098 non-null   object
#  6   STATE_NAME              3098 non-null   object
#  7   DIVISION_NAME           3098 non-null   object
#  8   COUNTY_NAME             3098 non-null   object
#  9   REGION_NAME             3098 non-null   object
#  10  POPULATION_GROUP_CODE   3095 non-null   object
#  11  POPULATION_GROUP_DESC   3095 non-null   object
#  12  OFFENSE_SUBCAT_ID       3098 non-null   object
#  13  OFFENSE_NAME            3098 non-null   object
#  14  OFFENSE_SUBCAT_NAME     3098 non-null   object
#  15  ACTUAL_COUNT            3098 non-null   int64
#  16  UNFOUNDED_COUNT         1129 non-null   float64
#  17  CLEARED_COUNT           3098 non-null   int64
#  18  JUVENILE_CLEARED_COUNT  3098 non-null   int64
# dtypes: float64(1), int64(4), object(14)
# memory usage: 460.0+ KB

# %%
# DATA_YEAR 
# The year in which the incident occurred.

ht["DATA_YEAR"].value_counts()
# Out:
# 2021    656
# 2020    639
# 2019    550
# 2018    395
# 2017    334
# 2016    253
# 2015    141
# 2014    124
# 2013      6
# Name: DATA_YEAR, dtype: int64

# %%
# ORI – ORIGINATING AGENCY IDENTIFIER (ORI) 
# This identifies the agency in which the offense occurred.

ht["ORI"].value_counts()
# Out:
# TXHPD0000    16
# TX2270100    16
# TX1010000    15
# TXSPD0000    15
# TXDPD0000    15
#              ..
# IL0820400     1
# IN0190200     1
# IN0320300     1
# IN0840100     1
# WY0110400     1
# Name: ORI, Length: 1460, dtype: int64

# %%
# PUB_AGENCY_NAME
# Agency name as it appears in FBI UCR Publications.

ht["PUB_AGENCY_NAME"].value_counts()
# Out:
# State Police:                                 221
# Greenville                                     20
# Austin                                         19
# Houston                                        17
# Dallas                                         17
#                                              ...
# Minnetrista                                     1
# Hubbard                                         1
# Refugio                                         1
# Pine                                            1
# Wyoming Division of Criminal Investigation      1
# Name: PUB_AGENCY_NAME, Length: 1177, dtype: int64

# %%
ht.groupby('PUB_AGENCY_NAME')['ACTUAL_COUNT'].sum()
# Out:
# PUB_AGENCY_NAME
# Aberdeen       64
# Abilene      3328
# Abingdon       64
# Abington       64
# Accomack      256
#              ...
# Yonkers        64
# York          128
# Ypsilanti      64
# Zavala        192
# Zumbrota       29
# Name: ACTUAL_COUNT, Length: 1177, dtype: int64

# %%
# PUB_AGENCY_UNIT 
# The specific unit name for which a Publication Agency report UCR data as.

ht["PUB_AGENCY_UNIT"].value_counts()
# Out:
# Kent County          7
# Sussex County        7
# New Castle County    5
# Ingham County        5
# Wayne County         4
#                     ..
# Muskegon County      1
# London               1
# Huntington County    1
# Clay County          1
# Welch                1
# Name: PUB_AGENCY_UNIT, Length: 129, dtype: int64

# %%
ht.groupby('PUB_AGENCY_UNIT')['ACTUAL_COUNT'].sum()
# Out:
# PUB_AGENCY_UNIT
# Accomack County      104
# Albemarle County      52
# Alleghany County      52
# Appomattox County     52
# Ashland               15
#                     ...
# Williamson           125
# Winfield              25
# Wise County          156
# Wythe County          52
# York County           60
# Name: ACTUAL_COUNT, Length: 129, dtype: int64

# %%
# AGENCY_TYPE_NAME 
# Type of agency that reports UCR data (city/county/federal agency, etc).

ht["AGENCY_TYPE_NAME"].value_counts()
# Out:
# City                     1999
# County                    795
# State Police              250
# Other                      19
# Other State Agency         19
# Tribal                     10
# University or College       3
# Federal                     3
# Name: AGENCY_TYPE_NAME, dtype: int64

# %%
ht.groupby('AGENCY_TYPE_NAME')['ACTUAL_COUNT'].sum()
# Out:
# AGENCY_TYPE_NAME
# City                     523453
# County                   177523
# Federal                      48
# Other                       724
# Other State Agency         3477
# State Police              16577
# Tribal                      158
# University or College        99
# Name: ACTUAL_COUNT, dtype: int64

# %%
# STATE_ABBR 
# This is the state abbreviation.

ht["STATE_ABBR"].value_counts()
# Out:
# TX    478
# MN    273
# FL    166
# WI    144
# GA    137
# TN    117
# MI    115
# MA    113
# CO    111
# KY    108
# IL    100
# WV     95
# NC     94
# WA     90
# VA     89
# MO     86
# SC     80
# MD     57
# IN     52
# CT     46
# AZ     42
# LA     40
# OK     38
# OH     36
# ND     36
# NV     33
# OR     31
# RI     31
# DE     24
# AR     18
# NE     18
# WY     18
# UT     16
# NH     15
# AK     15
# MT     14
# NJ     14
# VT     12
# AL     12
# ME     11
# IA     10
# NM     10
# PA      9
# SD      9
# HI      9
# MS      7
# ID      7
# NY      6
# FS      3
# KS      3
# Name: STATE_ABBR, dtype: int64

# %%
ht.groupby('STATE_ABBR')['ACTUAL_COUNT'].sum()
# Out:
# STATE_ABBR
# AK      1681
# AL      1199
# AR      1472
# AZ     17675
# CO     21230
# CT      3783
# DE      3621
# FL     40561
# FS        48
# GA     26356
# HI      1856
# IA       888
# ID       907
# IL     15974
# IN      8305
# KS       448
# KY     12759
# LA     15296
# MA     12361
# MD      5591
# ME       896
# MI     13138
# MN     62058
# MO     12644
# MS       370
# MT       978
# NC     12102
# ND      2932
# NE      1600
# NH      1079
# NJ       882
# NM      1920
# NV     75983
# NY       448
# OH      4530
# OK     12690
# OR      9221
# PA      1494
# RI      3567
# SC     10090
# SD       978
# TN     28285
# TX    186548
# UT     14794
# VA     12116
# VT       783
# WA     19419
# WI     30999
# WV      6036
# WY      1468
# Name: ACTUAL_COUNT, dtype: int64

# %%
# STATE_NAME 
# Full name of the state.

ht["STATE_NAME"].value_counts()
# Out:
# Texas             478
# Minnesota         273
# Florida           166
# Wisconsin         144
# Georgia           137
# Tennessee         117
# Michigan          115
# Massachusetts     113
# Colorado          111
# Kentucky          108
# Illinois          100
# West Virginia      95
# North Carolina     94
# Washington         90
# Virginia           89
# Missouri           86
# South Carolina     80
# Maryland           57
# Indiana            52
# Connecticut        46
# Arizona            42
# Louisiana          40
# Oklahoma           38
# Ohio               36
# North Dakota       36
# Nevada             33
# Oregon             31
# Rhode Island       31
# Delaware           24
# Arkansas           18
# Nebraska           18
# Wyoming            18
# Utah               16
# New Hampshire      15
# Alaska             15
# Montana            14
# New Jersey         14
# Vermont            12
# Alabama            12
# Maine              11
# Iowa               10
# New Mexico         10
# Pennsylvania        9
# South Dakota        9
# Hawaii              9
# Mississippi         7
# Idaho               7
# New York            6
# Federal             3
# Kansas              3
# Name: STATE_NAME, dtype: int64

# %%
hr1 = ht.groupby('STATE_NAME')['ACTUAL_COUNT'].sum()

# %%
# DIVISION_NAME 
# The geographic division in which the agency is located.

ht["DIVISION_NAME"].value_counts()
# Out:
# South Atlantic        742
# West South Central    574
# East North Central    447
# West North Central    435
# Mountain              251
# East South Central    244
# New England           228
# Pacific               145
# Middle Atlantic        29
# Other                   3
# Name: DIVISION_NAME, dtype: int64

# %%
# COUNTY_NAME 
# The name of the county within the state.

ht["COUNTY_NAME"].value_counts()
# Out:
# NOT SPECIFIED             83
# HENNEPIN                  61
# WASHINGTON                36
# JEFFERSON                 34
# KING                      34
#                           ..
# COLORADO                   1
# CONCHO                     1
# DALLAS, ELLIS, TARRANT     1
# SWISHER                    1
# GOSHEN                     1
# Name: COUNTY_NAME, Length: 711, dtype: int64

# %%
ht.groupby('COUNTY_NAME')['ACTUAL_COUNT'].sum()
# Out:
# COUNTY_NAME
# ACCOMACK                     360
# ADA                          601
# ADAMS                       2669
# ADAMS, ARAPAHOE, DOUGLAS    3520
# ADAMS, JEFFERSON             448
#                             ...
# WYTHE                         52
# YAKIMA                        64
# YANKTON                       64
# YORK                         508
# ZAVALA                       192
# Name: ACTUAL_COUNT, Length: 711, dtype: int64

# %%
# REGION_NAME 
# Geographic region in which the agency is located.

ht["REGION_NAME"].value_counts()
# Out:
# South        1560
# Midwest       882
# West          396
# Northeast     257
# Other           3
# Name: REGION_NAME, dtype: int64

# %%
# POPULATION_GROUP_CODE 
# Group 0 is possessions; 1-7 are cities; 8-9 are counties. 

ht["POPULATION_GROUP_CODE"].value_counts()
# Out:
# 2     378
# 3     370
# 5     319
# 9A    312
# 4     282
# 6     229
# 9B    210
# 1C    164
# 1B    141
# 8D    141
# 9D    138
# 8C     86
# 7      82
# 1A     77
# 8B     68
# 9C     50
# 8E     36
# 8A     11
# 9E      1
# Name: POPULATION_GROUP_CODE, dtype: int64

# %%
# POPULATION_GROUP_DESC 
# The name of the population groups.  

ht["POPULATION_GROUP_DESC"].value_counts()
# Out:
# Cities from 100,000 thru 249,999            378
# Cities from 50,000 thru 99,999              370
# Cities from 10,000 thru 24,999              319
# MSA counties 100,000 or over                312
# Cities from 25,000 thru 49,999              282
# Cities from 2,500 thru 9,999                229
# MSA counties from 25,000 thru 99,999        210
# Cities from 250,000 thru 499,999            164
# Cities from 500,000 thru 999,999            141
# Non-MSA counties under 10,000               141
# MSA counties under 10,000                   138
# Non-MSA counties from 10,000 thru 24,999     86
# Cities under 2,500                           82
# Cities 1,000,000 or over                     77
# Non-MSA counties from 25,000 thru 99,999     68
# MSA counties from 10,000 thru 24,999         50
# Non-MSA State Police                         36
# Non-MSA counties 100,000 or over             11
# MSA State Police                              1
# Name: POPULATION_GROUP_DESC, dtype: int64

# %%
# OFFENSE_SUBCAT_ID 
# A numeric code assigned to the Offense_Subcat_Name.

ht["OFFENSE_SUBCAT_ID"].value_counts()
# Out:
# HTCSA    2296
# HTIS      802
# Name: OFFENSE_SUBCAT_ID, dtype: int64

# %%
# OFFENSE_NAME
# Human Trafficking: Involuntary Servitude 
# Human trafficking involuntary servitude is defined as the obtaining of a person(s) 
# through recruitment, harboring, transportation, or provision, and subjecting such persons 
# by force, fraud, or coercion into involuntary servitude, peonage, debt bondage, or slavery 
# (not to include commercial sex acts).

ht["OFFENSE_NAME"].value_counts()
# Out:
# Human Trafficking    3098
# Name: OFFENSE_NAME, dtype: int64

# %%
# OFFENSE_SUBCAT_NAME 
# Commercial Sex Acts 
# Human trafficking commercial sex acts is defined as inducing a person by force, fraud, or coercion 
# to participate in commercial sex acts, or in which the person induced to perform such act(s) 
# has not attained 18 years of age.


ht["OFFENSE_SUBCAT_NAME"].value_counts()
# Out:
# Commercial Sex Acts      2296
# Involuntary Servitude     802
# Name: OFFENSE_SUBCAT_NAME, dtype: int64

# %%
# ACTUAL_COUNT 
# Total number of Human Trafficking offenses reported to the UCR Program.

ht["ACTUAL_COUNT"].value_counts()
# Out:
# 64      1248
# 128      344
# 192      179
# 0        155
# 256       94
#         ...
# 116        1
# 600        1
# 7296       1
# 294        1
# 183        1
# Name: ACTUAL_COUNT, Length: 197, dtype: int64

# %%
# UNFOUNDED_COUNT 
# Total number of false or baseless complaints reported to the UCR Program from law enforcement agencies. 

ht["UNFOUNDED_COUNT"].value_counts()
# Out:
# 0.0       980
# 64.0       54
# 128.0      26
# 192.0      12
# 512.0       9
# 256.0       9
# 448.0       5
# 320.0       4
# 384.0       3
# 768.0       3
# 5.0         2
# 1216.0      1
# 704.0       1
# 896.0       1
# 52.0        1
# 3264.0      1
# 1024.0      1
# 1536.0      1
# 9.0         1
# 49.0        1
# 30.0        1
# 686.0       1
# 25.0        1
# 640.0       1
# 47.0        1
# 56.0        1
# 1088.0      1
# 960.0       1
# 10.0        1
# 1664.0      1
# 43.0        1
# 832.0       1
# 51.0        1
# Name: UNFOUNDED_COUNT, dtype: int64

# %%
# CLEARED_COUNT 
# Total number of Human Trafficking offenses that were cleared or closed.

ht["CLEARED_COUNT"].value_counts()
# Out:
# 0       1684
# 64       607
# 128      170
# 192       75
# 256       55
#         ...
# 300        1
# 104        1
# 1856       1
# 168        1
# 44         1
# Name: CLEARED_COUNT, Length: 145, dtype: int64

# %%
# JUVENILE_CLEARED_COUNT 
# Total number of Human Trafficking offenses that involved a juvenile offender that were cleared or closed.

ht["JUVENILE_CLEARED_COUNT"].value_counts()
# Out:
# 0       2995
# 64        61
# 128       10
# 192        4
# 448        2
# 22         2
# 960        2
# 320        2
# 32         1
# 48         1
# 256        1
# 25         1
# 15         1
# 49         1
# 264        1
# 50         1
# 7          1
# 42         1
# 512        1
# 51         1
# 1024       1
# 686        1
# 832        1
# 1088       1
# 768        1
# 2176       1
# 53         1
# 45         1
# Name: JUVENILE_CLEARED_COUNT, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # Missing Data

# %%
ht.isnull().sum()
# Out:
# DATA_YEAR                    0
# ORI                          0
# PUB_AGENCY_NAME              0
# PUB_AGENCY_UNIT           2867
# AGENCY_TYPE_NAME             0
# STATE_ABBR                   0
# STATE_NAME                   0
# DIVISION_NAME                0
# COUNTY_NAME                  0
# REGION_NAME                  0
# POPULATION_GROUP_CODE        3
# POPULATION_GROUP_DESC        3
# OFFENSE_SUBCAT_ID            0
# OFFENSE_NAME                 0
# OFFENSE_SUBCAT_NAME          0
# ACTUAL_COUNT                 0
# UNFOUNDED_COUNT           1969
# CLEARED_COUNT                0
# JUVENILE_CLEARED_COUNT       0
# dtype: int64

# %%
# this will give us the percentage of missing data per row
ht.isnull().sum()/len(ht)
# Out:
# DATA_YEAR                 0.000000
# ORI                       0.000000
# PUB_AGENCY_NAME           0.000000
# PUB_AGENCY_UNIT           0.925436
# AGENCY_TYPE_NAME          0.000000
# STATE_ABBR                0.000000
# STATE_NAME                0.000000
# DIVISION_NAME             0.000000
# COUNTY_NAME               0.000000
# REGION_NAME               0.000000
# POPULATION_GROUP_CODE     0.000968
# POPULATION_GROUP_DESC     0.000968
# OFFENSE_SUBCAT_ID         0.000000
# OFFENSE_NAME              0.000000
# OFFENSE_SUBCAT_NAME       0.000000
# ACTUAL_COUNT              0.000000
# UNFOUNDED_COUNT           0.635571
# CLEARED_COUNT             0.000000
# JUVENILE_CLEARED_COUNT    0.000000
# dtype: float64

# %%
# double checking missing values
# variable in data, looking at the columns with missing data, greater than 0, representing missing data, O= object for categoricals
missing_data_categorical = [var for var in ht.columns if ht[var].isnull().mean()> 0
                            and ht[var].dtypes == "O"]

# %%
# double check columns with missing data
missing_data_categorical
# Out:
# ['PUB_AGENCY_UNIT', 'POPULATION_GROUP_CODE', 'POPULATION_GROUP_DESC']

# %% [markdown]
# ---
# ### PUB_AGENCY_UNIT

# %%
# double check percentages
ht['PUB_AGENCY_UNIT'].isnull().mean()
# Out:
# 0.9254357650096837

# %%
# double check percentages
ht['PUB_AGENCY_UNIT'].isnull().sum()
# Out:
# 2867

# %%
# double check percentages
ht['PUB_AGENCY_UNIT'].value_counts()
# Out:
# Kent County          7
# Sussex County        7
# New Castle County    5
# Ingham County        5
# Wayne County         4
#                     ..
# Muskegon County      1
# London               1
# Huntington County    1
# Clay County          1
# Welch                1
# Name: PUB_AGENCY_UNIT, Length: 129, dtype: int64

# %%
# double check percentages
ht['PUB_AGENCY_UNIT'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Delete Column, Misssing 93% of data

# %% [markdown]
# ---
# ### POPULATION_GROUP_CODE

# %%
# double check percentages
ht['POPULATION_GROUP_CODE'].isnull().mean()
# Out:
# 0.0009683666881859264

# %%
# double check percentages
ht['POPULATION_GROUP_CODE'].isnull().sum()
# Out:
# 3

# %%
# double check percentages
ht['POPULATION_GROUP_CODE'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Imputate the missing data, use the mode OR machine learning to predict and fill.
# #### - Misssing < 1% of data

# %%
ht['POPULATION_GROUP_CODE'].value_counts()
# Out:
# 2     378
# 3     370
# 5     319
# 9A    312
# 4     282
# 6     229
# 9B    210
# 1C    164
# 1B    141
# 8D    141
# 9D    138
# 8C     86
# 7      82
# 1A     77
# 8B     68
# 9C     50
# 8E     36
# 8A     11
# 9E      1
# Name: POPULATION_GROUP_CODE, dtype: int64

# %% [markdown]
# ---
# ### POPULATION_GROUP_DESC

# %%
# double check percentages
ht['POPULATION_GROUP_DESC'].isnull().mean()
# Out:
# 0.0009683666881859264

# %%
# double check percentages
ht['POPULATION_GROUP_DESC'].isnull().sum()
# Out:
# 3

# %%
# double check percentages
ht['POPULATION_GROUP_DESC'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Imputate the missing data, use the mode OR machine learning to predict and fill.
# #### - Misssing < 1% of data

# %% [markdown]
# ---
# ### UNFOUNDED_COUNT

# %%
# double check percentages
ht['UNFOUNDED_COUNT'].isnull().mean()
# Out:
# 0.6355713363460297

# %%
# double check percentages
ht['UNFOUNDED_COUNT'].isnull().sum()
# Out:
# 1969

# %%
# double check percentages
ht['UNFOUNDED_COUNT'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Delete Column, Misssing 64% of Data

# %% [markdown]
# ---

# %% [markdown]
# # Deleting Columns

# %% [markdown]
# - "STATE_ABBR"
# - "PUB_AGENCY_UNIT"
# - "UNFOUNDED_COUNT"
# - "ORI"
# - "PUB_AGENCY_NAME"
# - "REGION_NAME" (missing east coast)
# - "OFFENSE_NAME" (all human trafficing)
# - "OFFENSE_SUBCAT_ID"
# - "POPULATION_GROUP_DESC"
# - "POPULATION_GROUP_CODE"

# %%
ht.drop(["STATE_ABBR","PUB_AGENCY_UNIT","UNFOUNDED_COUNT","ORI","PUB_AGENCY_NAME","REGION_NAME","OFFENSE_NAME","OFFENSE_SUBCAT_ID","POPULATION_GROUP_DESC","POPULATION_GROUP_CODE"], axis=1, inplace=True)

# %%
ht.drop(["DIVISION_NAME"], axis=1, inplace=True)

# %%
ht.head()
# Out:
#    DATA_YEAR AGENCY_TYPE_NAME STATE_NAME         COUNTY_NAME  \
# 0       2013           County   Missouri            ST LOUIS
# 1       2013           County       Ohio               ALLEN
# 2       2013           County       Ohio               ALLEN
# 3       2013             City  Tennessee  HAMBLEN, JEFFERSON
# 4       2013             City  Tennessee              SHELBY
#
#      OFFENSE_SUBCAT_NAME  ACTUAL_COUNT  CLEARED_COUNT  JUVENILE_CLEARED_COUNT
# 0    Commercial Sex Acts           384            384                       0
# 1    Commercial Sex Acts            64             64                       0
# 2  Involuntary Servitude            64              0                       0
# 3    Commercial Sex Acts            64             64                       0
# 4    Commercial Sex Acts           192            128                       0

# %%
ht.columns
# Out:
# Index(['DATA_YEAR', 'AGENCY_TYPE_NAME', 'STATE_NAME', 'COUNTY_NAME',
#        'OFFENSE_SUBCAT_NAME', 'ACTUAL_COUNT', 'CLEARED_COUNT',
#        'JUVENILE_CLEARED_COUNT'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# # Visualizations

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# Quantitative data
sns.pairplot(ht)

# %% [markdown]
# ---
# # DATA_YEAR

# %%
ht['DATA_YEAR'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.distplot(ht['DATA_YEAR'])
# Out:
# /opt/homebrew/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='DATA_YEAR', ylabel='Density'>

# %% [markdown]
# ---
# # ACTUAL_COUNT

# %%
ht['ACTUAL_COUNT'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.distplot(ht['ACTUAL_COUNT'])
# Out:
# <AxesSubplot:xlabel='ACTUAL_COUNT', ylabel='Density'>

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# %%
sns.boxplot(data=ht, x='DATA_YEAR', y='ACTUAL_COUNT')
# Out:
# <AxesSubplot:xlabel='DATA_YEAR', ylabel='ACTUAL_COUNT'>

# %%
sns.catplot(data=ht, x='DATA_YEAR', y='ACTUAL_COUNT', kind= "box")

# %%
sns.boxplot(data=ht, x="DATA_YEAR", y="ACTUAL_COUNT",  color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, 
            linewidth=None, whis=1.5, ax=None)
# Out:
# <AxesSubplot:xlabel='DATA_YEAR', ylabel='ACTUAL_COUNT'>

# %%
sns.catplot(data=ht, x='DATA_YEAR', y='ACTUAL_COUNT', kind= "bar")

# %%
sns.catplot(data=ht, x='DATA_YEAR', y='ACTUAL_COUNT', kind= "box", height=8, aspect=15/8)

# %%
ht["ACTUAL_COUNT"].describe()
# Out:
# count     3098.000000
# mean       233.072628
# std        696.091641
# min        -64.000000
# 25%         64.000000
# 50%         64.000000
# 75%        168.000000
# max      13056.000000
# Name: ACTUAL_COUNT, dtype: float64

# %% [markdown]
# ---
# # CLEARED_COUNT

# %%
ht['CLEARED_COUNT'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.distplot(ht['CLEARED_COUNT'])
# Out:
# /opt/homebrew/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CLEARED_COUNT', ylabel='Density'>

# %% [markdown]
# ---
# # JUVENILE_CLEARED_COUNT

# %%
ht['JUVENILE_CLEARED_COUNT'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.distplot(ht['JUVENILE_CLEARED_COUNT'])
# Out:
# /opt/homebrew/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='JUVENILE_CLEARED_COUNT', ylabel='Density'>

# %% [markdown]
# ---
# # AGENCY_TYPE_NAME

# %%
ht['AGENCY_TYPE_NAME'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.catplot(data=ht, x='DATA_YEAR', y='AGENCY_TYPE_NAME', kind= "box", height=6, aspect=12/6)

# %%
sns.catplot(data=ht, x='ACTUAL_COUNT', y='AGENCY_TYPE_NAME', kind= "bar", height=6, aspect=20/6)

# %% [markdown]
# ---
# # STATE_NAME

# %%
#ht1 = ht[['STATE_NAME','ACTUAL_COUNT','DATA_YEAR']].groupby('STATE_NAME')\
#    .sum().sort_values(by=['ACTUAL_COUNT','DATA_YEAR'], ascending = False)

# %%
ht_sorted = ht.sort_values('ACTUAL_COUNT', ascending = False)

# %%
plt.style.use("fivethirtyeight")
plt.subplots(figsize=(20,8))
plt.xticks(rotation =75)
plt.title("Reported Cases by State")
plt.bar(ht_sorted["STATE_NAME"], ht_sorted["ACTUAL_COUNT"])
# Out:
# <BarContainer object of 3098 artists>

# %%
ht['STATE_NAME'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.catplot(data=ht, x='ACTUAL_COUNT', y='STATE_NAME', kind= "box", height=8, aspect=12/8)

# %%
sns.catplot(data=ht, x='ACTUAL_COUNT', y='STATE_NAME', kind= "bar" ,height=8.27, aspect=11.7/8.27)

# %% [markdown]
# ---
# # COUNTY_NAME

# %%
ht['COUNTY_NAME'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
top_counties = 100

plt.style.use("fivethirtyeight")
plt.subplots(figsize=(20,8))
plt.xticks(rotation =90)
plt.title(f"Top {top_counties} Counties")
plt.bar(ht_sorted["COUNTY_NAME"][:top_counties], ht_sorted["ACTUAL_COUNT"][:top_counties])
# Out:
# <BarContainer object of 100 artists>

# %%
sns.catplot(data=ht, x='COUNTY_NAME', y='ACTUAL_COUNT', kind= "bar", height=20, aspect=15/8.27)

# %% [markdown]
# ---
# # OFFENSE_SUBCAT_NAME

# %%
ht['OFFENSE_SUBCAT_NAME'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
crosstab_df_ACTUAL_COUNT = pd.crosstab(ht['DATA_YEAR'], ht['OFFENSE_SUBCAT_NAME'])
crosstab_df_ACTUAL_COUNT.plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='DATA_YEAR'>

# %%
sns.catplot(data=ht, x='DATA_YEAR', y='OFFENSE_SUBCAT_NAME', kind= "box")

# %% [markdown]
# ---
